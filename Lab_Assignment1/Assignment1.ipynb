# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab & Least Square Application*
# ### (100 Marks)

# %% [markdown]
# ## Preliminary: Certificate of Work
# ### (5 Marks)

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | First Name | Last Name | Signature | Hours | Contribution |
# | Member 2: | First Name | Last Name | Signature | Hours | Contribution |
# | Member 3: | First Name | Last Name | Signature | Hours | Contribution |
# | Member 4: | First Name | Last Name | Signature | Hours | Contribution |

# %% [markdown]
# ## Part 1: Printing to the Console
# ### (4 Marks)

# %%
# In the space below, please print "Hello, World! Welcome to the Student Gradebook Management System."
print("Hello, World! Welcome to the Student Gradebook Management System")
# Out:
# Hello, World! Welcome to the Student Gradebook Management System

# %%
# Fill in your information using the defined variables below:
# (1 mark)
lab_group_number = 23
intake_year = 2025
intake_semester = "Fall" #"Fall" or "Winter"
print(f"This is implemented by Group {lab_group_number}, for ENGG680 {intake_semester} of {intake_year}")

# Using f-strings and the variables above, print "This is implemented by Group <lab_group_number>, for ENGG680 <intake_semester> of <intake_year>"
# (1 marks)
# Out:
# This is implemented by Group 23, for ENGG680 Fall of 2025

# %%
# Similarly, create variables for each of your group members (eg. member_1, member_2....) and assign them your first names.
# Then, using f-strings and the variables above, print the following sentence:
# "Our Group Members include <member_1>, <member_2>, ..."
# (1 marks)
member_1 = "nazila"
member_2 = "Sandra"
member_3 = "Mazeda"
member_4 = "Sumaiya"
print(f"Our Group Members include {member_1}, {member_2}, {member_3} and {member_4}.")
# Out:
# Our Group Members include nazila, Sandra, Mazeda and Sumaiya.

# %%
# Use indexing to print "The subjects involved in this grading system is English and Math." using "subjects" below.
# (1 marks)
subjects = ("English", "Math")

# %% [markdown]
# ## Part 2: Python Fundamentals
# ### (11 Marks)

# %%
# Lists (2 marks)

# 1. Create a list of any 5 cities in Alberta.
# A list is a collection that can be changed (mutable) and holds multiple items.
cities = ["Calgary", "Edmonton", "Okotoks", "Lethbridge", "Medicine Hat"]

# 2. Print the list
# The print() function displays the current contents of the list.
print("Original list of cities:", cities)

# 3. Add a new city to list.
# The append() method adds an element to the end of the list.

cities.append("Grande Prairie")

# 4. Remove the second city using either remove() or pop().
# removes "Edmonton" (index 1)
# The pop() method removes an item at a specific index (0-based).
# Here, index 1 corresponds to the second item in the list.

cities.pop(1)

# 5. Sort the list alphabetically
# The sort() method arranges the list elements in ascending (A–Z) order.

cities.sort()

# 6. Print your final list
# Display the updated, alphabetically sorted list.

print("Final sorted list of cities:", cities)
# Out:
# Original list of cities: ['Calgary', 'Edmonton', 'Okotoks', 'Lethbridge', 'Medicine Hat']
# Final sorted list of cities: ['Calgary', 'Grande Prairie', 'Lethbridge', 'Medicine Hat', 'Okotoks']

# %%
# Tuples (2 marks)

# 1. Create a tuple of 3 favorite numbers.
# # A tuple is similar to a list, but it is immutable (cannot be changed after creation).

favorite_numbers = (7, 14, 21)

# 2. Print the tuple.
# The print() function displays all the values stored in the tuple.

print("My favorite numbers are:", favorite_numbers)

# 3. Try to modify the second element. Does that work? Explain.
# Tuples do not allow modification of individual items once they are created.

print("Tuples are immutable, meaning their elements cannot be changed once defined.")
# Out:
# My favorite numbers are: (7, 14, 21)
# Tuples are immutable, meaning their elements cannot be changed once defined.

# %%
# Dictionaries (2 marks)

# 1. Create a dictionary representing a mini visa form with keys like:
# "Name", "File Number", "Country", "Visa Type", "Expiry Year"
# Assign fictional values to the keys.
# Note: Dictionaries can contain values of different data types.
#
visa_form = {
    "Name": "Sandra",
    "File Number": "123456789",
    "Country": "Canada",
    "Visa Type": "Study Permit",
    "Expiry Year": 2027
}

# 2. Print the dictionary
#
print("Original Visa Form:", visa_form)

# 3. Add a new key "University" with a value
#
visa_form["University"] = "University of Calgary"

# 4. Update "Expiry Year" to a new year
#
visa_form["Expiry Year"] = 2028

# 5. Print the final dictionary
#
print("Updated Visa Form:", visa_form)
# Out:
# Original Visa Form: {'Name': 'Sandra', 'File Number': '123456789', 'Country': 'Canada', 'Visa Type': 'Study Permit', 'Expiry Year': 2027}
# Updated Visa Form: {'Name': 'Sandra', 'File Number': '123456789', 'Country': 'Canada', 'Visa Type': 'Study Permit', 'Expiry Year': 2028, 'University': 'University of Calgary'}

# %%
# Sets (2 marks)

# Set 1
subjects1 = {"Math", "English", "Physics", "Biology", "History"}

# Set 2
subjects2 = {"Math", "English", "Chemistry", "Geography", "Physics"}

# Tip: Use f-strings to print clear messages along with your output.
# Eg. "Union: ", "Intersection: "

# 1. Print both the sets
#
print(f"Subjects in Set 1: {subjects1}")
print(f"Subjects in Set 2: {subjects2}")

# 2. Print the union of sets
#
union_set = subjects1.union(subjects2)
print(f"Union (all unique subjects from both sets): {union_set}")

# 3. Print the intersection of sets
#
intersection_set = subjects1.intersection(subjects2)
print(f"Intersection (subjects common to both sets): {intersection_set}")

# 4. Print the difference (subjects1 - subjects2)
#
difference_set = subjects1.difference(subjects2)
print(f"Difference (subjects in Set 1 but not in Set 2): {difference_set}")
# Out:
# Subjects in Set 1: {'Biology', 'English', 'History', 'Physics', 'Math'}
# Subjects in Set 2: {'English', 'Chemistry', 'Geography', 'Physics', 'Math'}
# Union (all unique subjects from both sets): {'English', 'Math', 'Biology', 'Chemistry', 'Geography', 'History', 'Physics'}
# Intersection (subjects common to both sets): {'Math', 'English', 'Physics'}
# Difference (subjects in Set 1 but not in Set 2): {'Biology', 'History'}

# %%
# Classes and Function (3 marks)

# Step 1: Create a class BankAccount.
# Add class attribute bankname="Canada Bank"
# Add 2 instance attributes: account_holder (string) & balance (float, default value 0.0)
class BankAccount:
    bankname = "Canada Bank"
    def __init__(self, account_holder, balance=0.0):
       self.account_holder = account_holder
       self.balance = balance

# Step 2: Add methods
# 1. deposit(amount) -> Add amount to the balance
# 2. withdraw(amount) -> Subtract the amount if balance is sufficient, else print an error message
# 3. get_balance() -> Print Account holder's name and current balance
# 4. get_bankname() -> Print the class attribute (staticmethod)
# Note: Use f-strings to display the amount and updated balance whenever you call deposit() or withdraw()
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ${amount}. New balance: ${self.balance}")
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount}. Remaining balance: ${self.balance}")
        else:
            print("Error: Insufficient funds for this withdrawal.")
    def get_balance(self):
        print(f"Account Holder: {self.account_holder}, Current Balance: ${self.balance}")
    @staticmethod
    def get_bankname():
        print(f"Bank Name: {BankAccount.bankname}")

# Step 3: Test
# 1. Print the Bankname
# 2. Create an object of BankAccount with your name and an initial balance of 1000
# 3. Deposit 500
# 4. Withdraw 200
# 5. Print the final balance
BankAccount.get_bankname()
account1 = BankAccount("Sandra", 1000)
account1.deposit(500)
account1.withdraw(200)
account1.get_balance()
# Out:
# Bank Name: Canada Bank
# Deposited $500. New balance: $1500
# Withdrew $200. Remaining balance: $1300
# Account Holder: Sandra, Current Balance: $1300

# %% [markdown]
# ## Part 3: Using Pandas for Data Management and Analytics
# ### (15 marks)

# %%
# In the space below, please import the Pandas library
#
import pandas as pd

# %%
# Load the student grade CSV files into DataFrames using the defined variables
# (1 marks)

url_english = "https://raw.githubusercontent.com/NazilaAbedini/ENGG680_2025_Fall/main/Lab_Assignment1/studentGrades_English.csv"
url_math = "https://raw.githubusercontent.com/NazilaAbedini/ENGG680_2025_Fall/main/Lab_Assignment1/studentGrades_Math.csv"

df_english = pd.read_csv(url_english)
df_math = pd.read_csv(url_math)

# %%
# Print the first 5 rows of df_english using the .head method
#
print("First 5 rows of the English Grades DataFrame:")
print(df_english.head())
# Out:
# First 5 rows of the English Grades DataFrame:
#   firstName  lastName  studentID  grade
# 0      Emma     Smith      10959     95
# 1    Sophia  Robinson      75175     88
# 2      Emma    Taylor      42257     87
# 3     David  Robinson      55148     86
# 4   Stephen     Curry      30303     90

# %%
# Print the first 5 rows of df_math using the .head method
#
print("First 5 rows of the Math Grades DataFrame:")
print(df_math.head())
# Out:
# First 5 rows of the Math Grades DataFrame:
#   firstName lastName  studentID  grade
# 0     James    Jones      87707     92
# 1     Sarah    Swift      61026     98
# 2      Anne    Clark      90449     99
# 3      Ryan   Thomas      62137     89
# 4    Daniel    White      25477     87

# %%
# Merging the DataFrames on 'studentID'
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))

# %%
# Take a look at the data contained in the csv files. Why is studentID chosen as the key?
# (0.5 mark)
# In data analysis, a key column is used to link related records between different tables or files.
# studentID serves as a unique identifier (primary key).
# It prevents mismatched or duplicated data during merging.
# If you merged on “Name,” you could accidentally join the wrong students if two people share the same name.

# %%
# You will notice that all the column names got suffixes except studentID.
# Explain why pandas didn't add suffixes to the studentID column.
# studentID acts as the join key (shared and identical between both DataFrames).
# Pandas automatically keeps just one version of the key column.
# Suffixes are applied only to overlapping column names that are not used as keys.

# %%
# Let's calculate the average GPA across the two classes for each student
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# Now let's check the data! In the space below, please use the .head method to display the dataframe.
# (1 mark)
#
print("Student Grades with Calculated GPA:")
print(df_studentGrades.head())
# Out:
# Student Grades with Calculated GPA:
#   firstName_English lastName_English  studentID  grade_English firstName_Math  \
# 0              Emma            Smith      10959             95           Emma
# 1            Sophia         Robinson      75175             88         Sophia
# 2              Emma           Taylor      42257             87           Emma
# 3             David         Robinson      55148             86          David
# 4           Stephen            Curry      30303             90        Stephen
#
#   lastName_Math  grade_Math   GPA
# 0         Smith          90  92.5
# 1      Robinson          95  91.5
# 2        Taylor          85  86.0
# 3      Robinson          87  86.5
# 4         Curry          88  89.0

# %%
# Do you notice a problem? The rows for first name and last name have been duplicated!
# .drop(columns=['<column_name1>','<column_name2>'] is a Pandas method that can be used to drop columns.
# In the space below, drop the first name and last name associated with the math .csv file.
# (2 mark)
df_studentGrades =

# %%
# Let's display the data again. Use an appropriate method (hint: already used before)
# (0.5 mark)
#

# %%
# Let's also rename the first and last names appropriately.
# Complete the code in the space below by replacing "<>" with the proper column name
# (1 mark)

df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    '<>': 'lastName',
    '<>': 'englishGrade',
    '<>': 'mathGrade'
    })

# %%
# Now let's find out some statistics about our student grades!
# Please use an appropriate Pandas method in the space below to display statistical values like
# mean, standard deviation, min, max, and others.
# (1 mark)
#

# %%
# Do you notice a problem?
# Some statistics are not relevant. The average of studentIDs have no meaning in reality!
# Let's typecast each column appropriately so as to only get meaningful statistics.
# In the code below, replace '<>' by choosing between 'str' for string or 'float' for float
# to properly typecast each column.
# (1 marks)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(<>)
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype(<>)
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype(<>)
df_studentGrades['englishGrade'] = df_studentGrades['englishGrade'].astype(<>)
df_studentGrades['mathGrade'] = df_studentGrades['mathGrade'].astype(<>)
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype(<>)

# %%
# Now let's see our statistics!
df_studentGrades.describe()

# %%
# Now sort the merged dataframe so that it is in descending order based on GPA, and print it
# (1 mark)
df_studentsGPASorted =

# %%
# If we wanted to access the student with the highest gpa based on df_studentsGPASorted,
# does .iloc or .loc make more sense and why?
# (2 marks)
#

# %%
# Now using the method you specified, assign the variable below to the row containing the student with the highest GPA
# (1 mark)
top_student =

# %%
# Now print the student first name and last name with the highest GPA in this format:
# "The student with the highest GPA is <firstName> <lastName> with a GPA of <GPA>"
# (1 mark)
#

# %%
# We can use logical expressions to filter and print data. For example, let's print the students with math grades higher than 90:
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['mathGrade'] > 90]
print(df_mathGrade_over90)

# %%
# Use logical expressions, and print the students with math grades higher than 90, english grades higher than 80, and GPA greater than 85
df_bestStudents =

# %%
# Now print the students whos GPA are lower than 85
# (2 marks)
#

# %%
# Print the Top 3 Performers (highest GPA)
#

# %%
# Print the Bottom 2 Performers (lowest GPA)
#

# %% [markdown]
# ## Part 4: More Data Analytics using Pandas
# ### (18 marks)

# %%
# Select the column 'grade' from the original English grade dataset and print it
#
print("English Grades:")
print(df_english['grade'])
# Out:
# English Grades:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2899557486.py in <cell line: 0>()
#       2 #
#       3 print("English Grades:")
# ----> 4 print(df_english['grade'])
#
# NameError: name 'df_english' is not defined

# %%
# Select the column 'GPA' from the df_studentGrades and print it
#

# %%
# What is the data type of grade from the English grade dataset?
# (0.5 mark)
#

# What is the data type of GPA from the merged dataset?
# (0.5 mark)
#

# Is it different? Why?
# (1 mark)
#

# %%
# Load the student homeroom CSV file into a DataFrame using the following variable name
# (1 mark)
df_homeroom =

# %%
# Print first 5 rows of df_homeroom using the .head method
#

# %%
# Merge the studentHomerooms with the merged dataset & name it df_studentInfo. Make sure that the key you are joining on are the same typecast for both datasets.
# Also ensure that there are no redundant columns, and finally display the first few rows.
# Hint: try joining on more than one column to avoid having to drop redundant columns, ie. on=['studentID', '<ColumnA>', '<ColumnB>'] ...
# (5 marks)
#

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()

# Which homeroom has a higher GPA?
# (1 mark)
#

# %%
# Now let's work with multiple sorts. The .sort_values() method can sort by multiple columns, meaning you can specify a primary column and a secondary column for sorting.
# For example, by=['ColumnA', 'ColumnB'] will first sort by ColumnA and then by ColumnB.
# Create and print a DataFrame, df_studentsGPASorted_homeroom, which is sorted by homeRoom and then by GPA, both in descending order.
# (3 mark)
#

# %%
# Do you notice a problem with the indices? They are basically meaningless now that we have sorted by homeroom and GPA.

# The code below changes the index of the dataframe so that it is more intuitive.
#df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
#df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
#df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
#df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

#print(df_studentsGPASorted_homeroom)

# %%
# Describe what each coding line in the cell above is doing
# (4 marks)
#

# %%
# Given df_studentsGPASorted_homeroom, please find and print the students with the highest GPA in each homeroom using the .loc method.
# (2 marks)
#

# %% [markdown]
# ## Part 5: Using Matplotlib for Data Analytics
# ### (12 marks)

# %%
# In the space below, please import the matplotlib library
#

# %%
# Let's use matplotlib to display a histogram of the grades distribution
# Histograms are useful for seeing the distribution of the students grades

plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades', color='blue')

# Step 1: Use the line above as reference to create a histogram for the math grades
# (1 mark)
#

# Step 2: Ensure that your plot is descriptive, so use labels (x and y axis), a title, and a legend.
# Hint: Use the matplotlib .legend(loc='<location>') to add and place the legend.
# You can use 'upper left', 'upper right', 'lower left', and 'lower right' to specify the location.
# (3 marks)
#
plt.grid(True)

# Step 3: Use the .savefig('<image_title>'.png) to output an image file of the histogram.
# Please be sure to use a descriptive title!
# (1 mark)
#

plt.show()

# %%
# Let's also use matplotlib to display a scatter plot of English vs. Math grades
# Scatter plots are useful for seeing the relationship between two variables
plt.figure(figsize=(10, 6))

# Step 1: Use .scatter(x_data, y_data) to create a scatter plot using the English grades on the x-axis, and Math grades on the y-axis
# (2 mark)
#

# Step 1: Properly label the x and y axes as well as the title of your plot.
# (3 marks)
#
plt.grid(True)

# Step 2: Output an image file for the scatter plot with a descriptive file name
# (1 mark)
#

plt.show()

# %%
# From the scatter plot, is there a relationship between the Math and English grades?
# (1 mark)
#

# %% [markdown]
# ## Part 6: Linear LSE
# ### (35 marks)

# %% [markdown]
# ### Curve Fitting

# %% [markdown]
# ![curvefitting.png](data:image/png;base64,...)

# %% [markdown]
# ### Observations: values of a function f(a) in range of -π to π, contaminated with random noise

# %% [markdown]
# ### Unknown States: coefficients of polynomial functions for curve fitting

# %%
# step 1
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# step 2
# Load data.xlsx file, which contains the observations (with noise), variance of observations and true observations
# hint: use pandas library to parse excel file and use numpy library to convert it to array
# (1 mark)

url_data = "https://raw.githubusercontent.com/NazilaAbedini/ENGG680_2025_Fall/main/Lab_Assignment1/data.xlsx"

df_data = pd.read_excel(url_data)
arr_data = df_data.to_numpy()

#store the noisy observations, variance of observations and true observations into numpy arrays seperately
# (1 mark)
l = arr_data[:, 0]       # noisy observations (1st column)
l_var = arr_data[:, 1]   # variance of observations (2nd column)
l_true = arr_data[:, 2]  # true observations (3rd column)
# Display to verify
print("Data loaded successfully:")
print(df_data.head())
# Out:
# Data loaded successfully:
#            l  l_var     l_true
# 0 -16.194889     36 -17.000000
# 1 -15.936144    144 -17.289598
# 2 -38.690594    169 -17.579150
# 3 -15.768291    169 -17.868611
# 4 -19.354669      4 -18.157933

# %%
# step 3
# define the number of observation n
# (1 mark)
n = len(l)

# define the observation weight matrix P for LSE as identity matrix
# identity weight matrix simply means the observations will be unweighted in the following LSE
# (1 mark)
P = np.eye(n)

# define the range of function input(i.e., constants a), from start to end; and the numerical array of a
start = -1* np.pi
end = np.pi
a = np.linspace(start, end, n)
# Display to verify
print("Number of observations (n):", n)
print("Shape of weight matrix (P):", P.shape)
print("Range of a:", a[:5], "...", a[-5:])
# Out:
# Number of observations (n): 500
# Shape of weight matrix (P): (500, 500)
# Range of a: [-3.14159265 -3.1290011  -3.11640955 -3.10381799 -3.09122644] ... [3.09122644 3.10381799 3.11640955 3.1290011  3.14159265]

# %%
# step 4
# use the matplotlib to plot the true and noisy observations together in one single figure
# use scatter for noisy observation plotting
# for the true observation, label it as "f(a)"" and set color as 'k'
# for the noisy observation scatter plot, label it as "f(a) + e", set color as 'tab:blue', set marker as 'o' and set alpha as 0.3
# include proper axis labels, legend and title
# scale the range of x-axis to be -1 to 1
# keep this format for the rest of the plots in this lab assignment
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

# Plot the true observation line (f(a))
ax.plot(a, l_true, label='f(a)', color='k', linewidth=2)

# Plot the noisy observations as scatter points (f(a) + e)
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)

# Add labels, title, legend, and grid
ax.set_xlabel('a', fontsize=12)
ax.set_ylabel('ℓ', fontsize=12)
ax.set_title('True Function vs Noisy Observations', fontsize=14)
ax.legend()

# Scale x-axis range to -1 to 1
ax.set_xlim(-1, 1)

# Add grid and layout formatting

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()

# Display the plot
plt.show()

# %%
# step 5
# define a curve fitting function named fit_polynomial_curve
# the function should implement the linear least square estimation
# the function should include all important intermediate steps in LSE
# the input and output of the funciton are described in the comment below in red.
# please keep code clean and well-commented
# (7 marks)

def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Linear weighted least squares fit of a polynomial to noisy observations.

    Args:
        a   : (n,) array — function inputs (independent variable)
        l   : (n,) array — noisy observations (dependent variable)
        P   : (n,n) array — observation weight matrix (use I for unweighted)
        deg : int        — degree of the polynomial to fit

    Returns:
        x     : (deg+1,) array — estimated polynomial coefficients (x0 + x1 a + ... + x_deg a^deg)
        cov_x : (deg+1,deg+1) array — covariance matrix of the estimated coefficients
        apv   : float — a posteriori variance factor (goodness of fit)
        v     : (n,) array — residuals (A x - l)
    '''
    # ---- 1) Build the design (Vandermonde) matrix A: columns a^0, a^1, ..., a^deg
    # Shape: (n, deg+1)
    A = np.vander(a, N=deg+1, increasing=True)

    # ---- 2) Form normal equations: N = A^T P A, u = A^T P l
    AtP = A.T @ P
    N = AtP @ A
    u = AtP @ l

    # ---- 3) Solve for coefficients x (use solve if well-conditioned; fall back to pinv otherwise)
    try:
        x = np.linalg.solve(N, u)
    except np.linalg.LinAlgError:
        x = np.linalg.pinv(N) @ u  # robust fallback

    # ---- 4) Compute residuals v = A x - l
    v = A @ x - l

    # ---- 5) Compute a posteriori variance factor (goodness of fit)
    n_obs = A.shape[0]
    n_unk = A.shape[1]
    dof = max(n_obs - n_unk, 1)  # avoid division by zero
    apv = float(v.T @ P @ v) / dof

    # ---- 6) Covariance of the estimated coefficients
    try:
        N_inv = np.linalg.inv(N)
    except np.linalg.LinAlgError:
        N_inv = np.linalg.pinv(N)
    cov_x = apv * N_inv

    return (x, cov_x, apv, v)

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 2, 4, 6
# (1 marks)
# Degree 2
x2, cov_x2, apv2, v2 = fit_polynomial_curve(a, l, P, deg=2)

# Degree 4
x4, cov_x4, apv4, v4 = fit_polynomial_curve(a, l, P, deg=4)

# Degree 6
x6, cov_x6, apv6, v6 = fit_polynomial_curve(a, l, P, deg=6)

# Display results for quick verification
print("Degree 2 coefficients:", x2)
print("Degree 4 coefficients:", x4)
print("Degree 6 coefficients:", x6)
# Out:
# Degree 2 coefficients: [-16.72496774   7.25633807   0.03979476]
# Degree 4 coefficients: [-1.65770980e+01  1.96396137e+01 -1.09433276e-01 -2.08281013e+00
#   1.75697706e-02]
# Degree 6 coefficients: [-1.63864293e+01  2.28207004e+01 -5.13527465e-01 -3.58096979e+00
#   1.39914556e-01  1.36073672e-01 -9.05453557e-03]

# %%
# step 7
# use the estimated coefficients x and constants array a, construct polynomial functions for each degree
# hint: use polyval function from numpy library (check input argument carefully)
# (1 marks)
# import numpy as np
quadratic_uw = np.polyval(x2[::-1], a)   # degree 2 fit
quartic_uw   = np.polyval(x4[::-1], a)   # degree 4 fit
hexic_uw     = np.polyval(x6[::-1], a)   # degree 6 fit

# %%
# step 8
# use the matplotlib to plot each polynomial function, noisy observations l, true observations l_true, together in one single figure
# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
# Plot the true function
ax.plot(a, l_true, label='True f(a)', color='k', linewidth=2)

# Plot noisy observations
ax.scatter(a, l, label='Noisy Observations f(a) + e', color='tab:blue', marker='o', alpha=0.3)

# Plot polynomial fits
ax.plot(a, quadratic_uw, color='orange', linewidth=2, label='Quadratic Fit (deg=2)')
ax.plot(a, quartic_uw, color='green', linewidth=2, label='Quartic Fit (deg=4)')
ax.plot(a, hexic_uw, color='red', linewidth=2, label='Hexic Fit (deg=6)')

# Labels, title, and legend
ax.set_xlabel('a', fontsize=12)
ax.set_ylabel('ℓ', fontsize=12)
ax.set_title('Polynomial Fits of Various Degrees vs True and Noisy Observations', fontsize=14)
ax.legend(loc='upper left')

# Grid and layout

ax.grid(True, which='both',ls='-',color='0.65')

fig.tight_layout()

# %%
# step 9
# print the a posterier variance factor for each polynomial function
# (3 marks)
print("A Posteriori Variance Factors (Goodness of Fit):")
print(f"Degree 2 Polynomial (Quadratic): {apv2:.6f}")
print(f"Degree 4 Polynomial (Quartic):   {apv4:.6f}")
print(f"Degree 6 Polynomial (Hexic):     {apv6:.6f}")
# Out:
# A Posteriori Variance Factors (Goodness of Fit):
# Degree 2 Polynomial (Quadratic): 163.056153
# Degree 4 Polynomial (Quartic):   66.248428
# Degree 6 Polynomial (Hexic):     63.858632

# %%
# step 10
# compute and print the norm between the predicted observations (output from each polynomial function) and the true observations
# (3 marks)
# Compute Euclidean (L2) norm between predicted and true values
norm_deg2 = np.linalg.norm(quadratic_uw - l_true)
norm_deg4 = np.linalg.norm(quartic_uw - l_true)
norm_deg6 = np.linalg.norm(hexic_uw - l_true)

# Print results
print("Norm (Difference between predicted and true observations):")
print(f"Degree 2 Polynomial (Quadratic): {norm_deg2:.6f}")
print(f"Degree 4 Polynomial (Quartic):   {norm_deg4:.6f}")
print(f"Degree 6 Polynomial (Hexic):     {norm_deg6:.6f}")
# Out:
# Norm (Difference between predicted and true observations):
# Degree 2 Polynomial (Quadratic): 229.075253
# Degree 4 Polynomial (Quartic):   38.398621
# Degree 6 Polynomial (Hexic):     17.777307

# %%
# step 11
# comment on the results of a posterier variance factor and norm, what pattern do you observe
# (2 marks)
# As the polynomial degree increases (from 2 → 4 → 6),
# both the a posteriori variance factor (apv) and the norm between predicted
# and true observations decrease.
# This pattern indicates that higher-degree polynomials provide a closer fit to the data
# by capturing more of the variation in the noisy observations.
# However, if the degree continues to increase, the model could begin to overfit —
# fitting noise rather than the underlying true function.
# Therefore, the goal is to find an optimal degree that minimizes error
# without overfitting the noise.

# %%
# step 12
# now, let's define the P matrix with the proper weights of observation
# use the variance of observation l_var, define P matrix
# (1 mark)
P = np.diag(1 / l_var)

# %%
# step 13
# repeat the steps 6-10, using the proper P matrix
# (7 marks)
# --- 6) Fit weighted polynomial curves (degrees 2, 4, 6)
x2_w, cov_x2_w, apv2_w, v2_w = fit_polynomial_curve(a, l, P, deg=2)
x4_w, cov_x4_w, apv4_w, v4_w = fit_polynomial_curve(a, l, P, deg=4)
x6_w, cov_x6_w, apv6_w, v6_w = fit_polynomial_curve(a, l, P, deg=6)

# --- 7) Evaluate polynomial predictions (remember: np.polyval expects descending order)
quadratic_w = np.polyval(x2_w[::-1], a)
quartic_w   = np.polyval(x4_w[::-1], a)
hexic_w     = np.polyval(x6_w[::-1], a)

# --- 8) Plot weighted fits with true and noisy observations
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

# True function and noisy observations
ax.plot(a, l_true, label='True f(a)', color='k', linewidth=2)
ax.scatter(a, l, label='Noisy Observations f(a)+e', color='tab:blue', marker='o', alpha=0.3)

# Weighted polynomial fits (colors per earlier convention)
ax.plot(a, quadratic_w, color='orange', linewidth=2, label='Weighted Quadratic (deg=2)')
ax.plot(a, quartic_w,   color='green',  linewidth=2, label='Weighted Quartic (deg=4)')
ax.plot(a, hexic_w,     color='red',    linewidth=2, label='Weighted Hexic (deg=6)')

ax.set_xlabel('a', fontsize=12)
ax.set_ylabel('ℓ', fontsize=12)
ax.set_title('Weighted Polynomial Fits vs True and Noisy Observations', fontsize=14)
ax.legend(loc='upper left')
ax.grid(True, which='both', ls='-', color='0.65')
fig.tight_layout()
plt.show()

# --- 9) Print a posteriori variance factors (goodness of fit) for weighted case
print("Weighted A Posteriori Variance Factors (Goodness of Fit):")
print(f"Weighted Degree 2 (Quadratic): {apv2_w:.6f}")
print(f"Weighted Degree 4 (Quartic):   {apv4_w:.6f}")
print(f"Weighted Degree 6 (Hexic):     {apv6_w:.6f}")

# --- 10) Compute and print norms vs. true observations for weighted predictions
norm_deg2_w = np.linalg.norm(quadratic_w - l_true)
norm_deg4_w = np.linalg.norm(quartic_w   - l_true)
norm_deg6_w = np.linalg.norm(hexic_w     - l_true)

print("\nWeighted Norms (Predicted vs True Observations):")
print(f"Weighted Degree 2 (Quadratic): {norm_deg2_w:.6f}")
print(f"Weighted Degree 4 (Quartic):   {norm_deg4_w:.6f}")
print(f"Weighted Degree 6 (Hexic):     {norm_deg6_w:.6f}")
# Out:
# Weighted A Posteriori Variance Factors (Goodness of Fit):
# Weighted Degree 2 (Quadratic): 12.072979
# Weighted Degree 4 (Quartic):   1.144187
# Weighted Degree 6 (Hexic):     0.944928
#
# Weighted Norms (Predicted vs True Observations):
# Weighted Degree 2 (Quadratic): 230.800214
# Weighted Degree 4 (Quartic):   36.255546
# Weighted Degree 6 (Hexic):     6.553038

# %%
# step 14
# Compare the results of a posterier variance factor and norm from unweighted LSE and weighted LSE, what phenomena do you observe? Explain this phenomena.
# (2 marks)
# The weighted LSE results show smaller a posteriori variance factors and lower norms
# compared to the unweighted LSE.
# This indicates that the weighted model provides a better overall fit to the true function.
#
# The reason is that weighting accounts for the reliability of each observation:
# measurements with smaller variance (more precise) are given higher weights,
# while noisier observations with larger variance influence the fit less.
# As a result, the weighted LSE reduces the effect of outliers or high-variance data,
# leading to a more accurate and stable estimation of the polynomial coefficients.
